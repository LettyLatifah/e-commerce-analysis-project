# %% [markdown]
# # Proyek Analisis Data: E-Commerce Public Dataset
# - Nama: Letty Latifani Arifah
# - Email: lettylatifah15@gmail.com
# - Id Dicoding: lettylatifah

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Produk apa saja yang paling diminati dan paling sedikit diminati oleh pelanggan?
# - Produk kategori apa yang memiliki review paling baik dan paling rendah?

# %% [markdown]
# ## Menyiapkan semua library yang dibutuhkan
# Ada empat library yang dibutuhkan pada proyek analisis data yang akan dilakukan, yaitu library Pandas, Numpy, Matplotlib, dan Seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
# Memproses seluruh data CSV dan melakukan inisiasi ke dalam dataframe

customers_df = pd.read_csv("e-commerce-dataset/customers_dataset.csv")
geolocation_df = pd.read_csv("e-commerce-dataset/geolocation_dataset.csv")
order_items_df = pd.read_csv("e-commerce-dataset/order_items_dataset.csv")
order_payment_df = pd.read_csv("e-commerce-dataset/order_payments_dataset.csv")
order_reviews_df = pd.read_csv("e-commerce-dataset/order_reviews_dataset.csv")
orders_df = pd.read_csv("e-commerce-dataset/orders_dataset.csv")
product_category_name_translation_df = pd.read_csv("e-commerce-dataset/product_category_name_translation.csv")
products_df = pd.read_csv("e-commerce-dataset/products_dataset.csv")
sellers_df = pd.read_csv("e-commerce-dataset/sellers_dataset.csv")

# %%
# menampilkan lima data teratas dataset customer
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
# menampilkan lima data teratas dataset geolocation
geolocation_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
# menampilkan lima data teratas dataset order items
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
# menampilkan lima data teratas dataset order payment
order_payment_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
# menampilkan lima data teratas dataset order reviews
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
# menampilkan lima data teratas dataset orders
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
# menampilkan lima data teratas dataset products
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# Data produk yang diperoleh pada proses ini ternyata menggunakan bahasa asing, oleh karena itu harus dilakukan penerjemahan ke dalam bahasa inggris dengan menggunakan dataset product_category_name_translation.

# %%
# menampilkan lima data teratas dataset product category name translation
product_category_name_translation_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
products_df =  products_df.merge(product_category_name_translation_df, left_on='product_category_name', right_on='product_category_name', how='left')
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
# menampilkan lima data teratas dataset sellers
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ### Assessing Data
# Pada proyek ini hanya akan melakukan assesing data pada beberapa data saja. Beberapa data yang akan digunakan meliputi data produk, reviews, dan order items. Proses ini dilakukan pengecekan untuk menilai kualitas data yang akan digunakan. Pengecekan data meliputi pengecekan tipe data, data yang hilang (missing value), dan duplikasi data.

# %% [markdown]
# #### Assessing Data Product

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_id                     32951 non-null  object
#  1   product_category_name          32341 non-null  object
#  2   product_name_lenght            32341 non-null  float64
#  3   product_description_lenght     32341 non-null  float64
#  4   product_photos_qty             32341 non-null  float64
#  5   product_weight_g               32949 non-null  float64
#  6   product_length_cm              32949 non-null  float64
#  7   product_height_cm              32949 non-null  float64
#  8   product_width_cm               32949 non-null  float64
#  9   product_category_name_english  32328 non-null  object
# dtypes: float64(7), object(3)
# memory usage: 2.5+ MB

# %%
print("Jumlah duplikasi data: ", products_df.duplicated().sum())
products_df.describe()
# Out:
# Jumlah duplikasi data:  0
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %%
products_df.isna().sum()
# Out:
# product_id                         0
# product_category_name            610
# product_name_lenght              610
# product_description_lenght       610
# product_photos_qty               610
# product_weight_g                   2
# product_length_cm                  2
# product_height_cm                  2
# product_width_cm                   2
# product_category_name_english    623
# dtype: int64

# %% [markdown]
# Berdasarkan assessing data yang telah dilakukan, tidak ada kesalahan pada penggunaan tipe data pada kolom, dan tidak ditemukan duplikasi data. Namun terdapat cukup banyak data yang hilang pada data produk hampir seluruh kolom kecuali kolom product_id.

# %% [markdown]
# #### Assessing Data Order Reviews

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
print("Jumlah duplikasi data :", order_reviews_df.duplicated().sum())
order_reviews_df.describe()
# Out:
# Jumlah duplikasi data : 0
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %% [markdown]
# Berdasarkan proses assessing data yang dilakukan pada dataframe Order Reviews, terdapat penggunaan tipe data yang kurang tepat pada kolom review_creation_date dan review_answer_timestamp. Pada Kedua kolom tersebut menggunakan tipe data object untuk kolom yang mendeskripsikan penggunaan waktu, sebaiknya kolom tersebut menggunakan tipe data datetime. Selain itu ditemukan banyak data yang hilang pada kolom review_comment_title dan review_comment_message.

# %% [markdown]
# #### Assessing Data Order Items

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
print("Jumlah Duplikasi data :", order_items_df.duplicated().sum())
order_items_df.describe()
# Out:
# Jumlah Duplikasi data : 0
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %%
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %% [markdown]
# Berdasarkan assessing data yang dilakukan pada DataFrame Order Items, terdapat penggunaan tipe data yang kurang tepat pada kolom shipping_limit_date, pada kolom tersebut menggunakan tipe data object. Penggunaan tipe data yang lebih tepat pada kolom shipping_limit_date seharusnya adalah tipe data datetime. Selain itu, tidak ditemukan kejanggalan lain pada DataFrame Order Items.

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Pada proses Cleaning Data akan dilakukan pembersihan data berdasarkan kejanggalan yang telah ditemukan pada proses Assessing Data sebelumnya.
# Berikut ini cleaning data yang harus dilakukan pada dataframe yang telah dilakukan assessing data:
# 1. Product DataFrame
#   - Data hilang
# 2. Orders Review DataFrame
#   - Data hilang
#   - Tipe data salah
# 3. Order Items DataFrame
#   - Tipe data salah

# %% [markdown]
# #### Cleaning Data Products

# %%
# melihat daftar data yang hilang
products_df[products_df.product_category_name.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %% [markdown]
# Dapat dilihat pada kolom diatas, terdapat banyak sekali data yang hilang. Kerena semua kategori produk tidak diketahui, maka sebaiknya data tersebut dihapus.

# %%
products_df.dropna(axis=0, inplace=True)

# %%
products_df.isna().sum()
# Out:
# product_id                       0
# product_category_name            0
# product_name_lenght              0
# product_description_lenght       0
# product_photos_qty               0
# product_weight_g                 0
# product_length_cm                0
# product_height_cm                0
# product_width_cm                 0
# product_category_name_english    0
# dtype: int64

# %% [markdown]
# #### Cleaning Data Order Reviews

# %%
# mengecek tipe data sebelum diubah
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
# mengubah tipe data kolom menjadi datetime
datetime_columns = ["review_creation_date", "review_answer_timestamp"]

for column in datetime_columns:
  order_reviews_df[column] = pd.to_datetime(order_reviews_df[column])

# %%
# pengecekan tipe data setelah diubah menjadi datetime
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %%
# mengecek data hilang 
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
order_reviews_df[order_reviews_df["review_score"] == 5]
# Out:
#                               review_id                          order_id  \
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# 6      07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# ...                                 ...                               ...
# 99217  c6b270c61f67c9f7cb07d84ea8aeaf8b  48f7ee67313eda32bfcf5b9c1dd9522d
# 99218  af2dc0519de6e0720ef0c74292fb4114  d699c734a0b1c8111f2272a3f36d398c
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
#
#        review_score review_comment_title  \
# ...

# %%
order_reviews_df[order_reviews_df["review_score"] == 4]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 9      8670d52e15e00043ae7de4c01cc2fe06  b9bf720beb4ab3728760088589c62129
# 12     4b49719c8a200003f700d3d986ea1a19  9d6f15f95d01e79bd1349cc208361f09
# 13     23f75a37effc35d9a915b4e1ad483793  2eaf8e099d871cd5c22b83b5ea8f6e0e
# 20     a2ff510ca4e059c3fefc7a7866571f6f  a9953b2f0b1665ac7586cc5a6ac8f58c
# ...                                 ...                               ...
# 99193  d57774fa9cf83a0a034c62890e1d93d2  2bf1d83ac1f9e3bb2a9c497d3de0e866
# 99194  9819f7e9071ba1cfcf8c7368def8b529  e4dba31c8df21a1169949334f2639889
# 99195  98fa3c0116272fb0d0a39ff3aeeb4e6a  95123e166ec553efe0364686f36d5ac4
# 99205  98fffa80dc9acbde7388bef1600f3b15  d398e9c82363c12527f71801bf0e6100
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
#
#        review_score review_comment_title  \
# ...

# %% [markdown]
# Berdasarkan pengecekan ulang pada DataFrame Order Reviews dengan parameter yang lebih spesifik yaitu review_score, ditemukan banyak data Order Reviews yang memiliki nilai pada kolom review_score namun tidak memiliki nilai pada review_comment_title dan review_comment_message. Hal tersebut bisa saja disebabkan oleh pelanggan yang hanya memberikan review score tetapi tidak ingin memberikan comment title dan comment message. Jadi kita tidak bisa melakukan penghapusan data pada data yang hilang karena akan mempengaruhi review score pada produk lainnya karena jumlah data yang hilang melebihi 50% jumlah DataFrame order_reviews, jadi data tersebut bisa dibiarkan saja seperti itu.

# %% [markdown]
# #### Cleaning Data Order Items

# %%
# pengecekan tipe data sebelum diubah
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
# mengubah tipe data kolom menjadi datetime
datetime_columns_3 = ["shipping_limit_date"]

for column in datetime_columns_3:
  order_items_df[column] = pd.to_datetime(order_items_df[column])

# %%
# pengecekan tipe data setelah diubah
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %% [markdown]
# #### Cleaning Data Orders

# %%
# pengecekan tipe data sebelum diubah
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
# mengubah tipe data kolom menjadi datetime
datetime_columns_2 = ["order_purchase_timestamp", 
                      "order_approved_at", 
                      "order_delivered_carrier_date",
                      "order_delivered_customer_date",
                      "order_estimated_delivery_date"]

for column in datetime_columns_2:
  orders_df[column] = pd.to_datetime(orders_df[column])

# %%
# pengecekan tipe data setelah diubah
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# Data yang hilang pada DataFrame Orders terdapat pada lima kolom, kehhilangan data tersebut berkaitan dengan kolom order_status. Data yang memiliki status "shipped" dan "canceled" dapat mempengaruhi kehilangan data pada kolom lainnya, sehingga lima kolom lainnya memiliki nilai kosong atau data hilang. Jadi kehilangan data tersebut bukan termasuk dalam kesalahan pada DataFrame karena ada data lainnya yang mempengaruhi data tersebut. Sehingga kehilangan data pada DataFrame Orders dapat diabaikan saja.

# %%
orders_df[orders_df.order_status == "shipped"].head()
# Out:
#                              order_id                       customer_id  \
# 44   ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 154  6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# 162  36530871a5e80138db53bcfd8a104d90  4dafe3c841d2d6cc8a8b6d25b35704b9
# 231  4d630f57194f5aba1a3d12ce23e71cd9  6d491c9fe2f04f6e2af6ec033cd8907c
# 299  3b4ad687e7e5190db827e1ae5a8989dd  1a87b8517b7d31373b50396eb15cb445
#
#     order_status order_purchase_timestamp   order_approved_at  \
# 44       shipped      2018-06-04 16:44:48 2018-06-05 04:31:18
# 154      shipped      2018-01-10 11:33:07 2018-01-11 02:32:30
# 162      shipped      2017-05-09 11:48:37 2017-05-11 11:45:14
# 231      shipped      2017-11-17 19:53:21 2017-11-18 19:50:31
# 299      shipped      2018-06-28 12:52:15 2018-06-28 13:11:09
#
#     order_delivered_carrier_date order_delivered_customer_date  \
# 44           2018-06-05 14:32:00                           NaT
# ...

# %%
orders_df[orders_df.order_status == "canceled"].head()
# Out:
#                               order_id                       customer_id  \
# 397   1b9ecfe83cdc259250e1a8aca174f0ad  6d6b50b66d79f80827b6d96751528d30
# 613   714fb133a6730ab81fa1d3c1b2007291  e3fe72696c4713d64d3c10afe71e75ed
# 1058  3a129877493c8189c59c60eb71d97c29  0913cdce793684e52bbfac69d87e91fd
# 1130  00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801  ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
#
#      order_status order_purchase_timestamp   order_approved_at  \
# 397      canceled      2018-08-04 14:29:27 2018-08-07 04:10:26
# 613      canceled      2018-01-26 21:34:08 2018-01-26 21:58:39
# 1058     canceled      2018-01-25 13:34:24 2018-01-25 13:50:20
# 1130     canceled      2018-08-28 15:26:39                 NaT
# 1801     canceled      2018-09-20 13:54:16                 NaT
#
#      order_delivered_carrier_date order_delivered_customer_date  \
# 397                           NaT                           NaT
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Products Data

# %%
products_df.sample(10)
# Out:
#                              product_id        product_category_name  \
# 23472  84dd5aaecdb39b406c39de952b13f394                    papelaria
# 20576  0721efe2bcae3223969332d77f0182bc                    telefonia
# 12760  005030ef108f58b46b78116f754d8d38                   perfumaria
# 4113   9682ad2500ae8b2609e6a88eb0cbc5bb                casa_conforto
# 12991  d8b8e82856a488b2cf5bcf21407efa8d  fashion_bolsas_e_acessorios
# 8780   47259ce36f2aa500b4e7528100998ed4                    telefonia
# 23157  c04ebe208ae260f39b376cd6ffbd0b14                    telefonia
# 19814  8e96968cb84d255da9c325f3906909ad              livros_tecnicos
# 23730  798d450aedc86f840c17c0aabd4e9303              cama_mesa_banho
# 3572   775882cccdd5199956853d6117b0e650             eletrodomesticos
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 23472                 54.0                       395.0                 1.0
# ...

# %%
products_df.describe(include="all")
# Out:
#                               product_id product_category_name  \
# count                              32327                 32327
# unique                             32327                    71
# top     1e9e8ef04dbcff4541ed26657ea517e5       cama_mesa_banho
# freq                                   1                  3029
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# count          32327.000000                32327.000000        32327.000000
# ...

# %%
products_df.groupby("product_category_name_english").product_id.count().sort_values(ascending=False)
# Out:
# product_category_name_english
# bed_bath_table               3029
# sports_leisure               2867
# furniture_decor              2657
# health_beauty                2444
# housewares                   2335
#                              ...
# tablets_printing_image          9
# home_comfort_2                  5
# fashion_childrens_clothes       5
# security_and_services           2
# cds_dvds_musicals               1
# Name: product_id, Length: 71, dtype: int64

# %% [markdown]
# Berdasarkan hasil Explore Data yang dilakukan, diperoleh data sebagai berikut:
# - Produk yang paling banyak yaitu dari kategori bed_bath_table sebanyak 3.029 produk dan produk yang paling sedikit yaitu dari kategori cds_dvds_musicals sebanyak 1 buah saja.

# %% [markdown]
# ### Explore Order Reviews Data

# %%
order_reviews_df.sample(10)
# Out:
#                               review_id                          order_id  \
# 4390   24655af19012f21f726150f7f6dded98  3a23294a91e71ba11196b90c9e51d44d
# 16573  88c82da4452182a8e3802603b862c44c  108041cfc40e06d2d7a97c426bc6b90f
# 80948  1ab4a4245e08bfcd1065f2389b75b1b7  70786de34f40ec53c3e3d31460dfb880
# 52395  a41b8cc3a8fc6f63c9562d983f26fb54  09cbcd1a5e559da522327abcf7e30dda
# 58278  e5475562cc2a149c722bb0f952d88b3b  33e7761758c09be48d777723b0c32648
# 9561   818eccd60e925c79192738171b9a1462  dc82ca767bb8a029bf346c1cb24bbdda
# 28839  d7fdabf4953de747acaf30c51ccc0481  6f91268a084c516d7ad2ede51294e10e
# 87021  66ffcffea5e3f40f10c8d35cd2d8ad9e  05e168bd339a82dc2739b847d4ca99f8
# 10261  85bc7a8d8ed3b1946cb215d8d84f5c73  9b2d0b62b218b964a7d93e0df5e07b7f
# 52087  d0310aa6e7716d84a729cbbf4072e682  7581c7decedb7d7f4310ef8313f935a7
#
#        review_score review_comment_title  \
# 4390              4                  NaN
# 16573             4                  NaN
# ...

# %%
order_reviews_df.describe(include="all")
# Out:
#                                review_id                          order_id  \
# count                              99224                             99224
# unique                             98410                             98673
# top     7b606b0d57b078384f0b58eac1d41d78  c88b1d1b157a9999ce368f218a407141
# freq                                   3                                 3
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#         review_score review_comment_title review_comment_message  \
# ...

# %%
order_reviews_df.groupby("review_score").order_id.nunique()
# Out:
# review_score
# 1    11393
# 2     3148
# 3     8160
# 4    19098
# 5    57076
# Name: order_id, dtype: int64

# %% [markdown]
# ### Explore Order Items Data

# %%
order_items_df.sample(10)
# Out:
#                                 order_id  order_item_id  \
# 95528   d8af0191c574aef677e1530618925317              1
# 13299   1e2ff126f1e0eccce95474029d18617c              1
# 781     01cadf993df82ff0e318addbd022f0fe              1
# 23028   349982921dd24028676e068b97e126c8              1
# 40016   5b162b218962d6f3b7c0d0f3bec7920d              1
# 109208  f82c97fae29a4711ae4800dadd3487b1              1
# 32673   4a0c442614599b83a064e2889049712c              1
# 16193   24ffe5543b23e12690af44dda7fd5ad2              1
# 13889   1f990d2b7b5a992e60e4c0ac2ff40f36              1
# 89527   cb54c9069dc123fa6cfca4b4cf94eb9c              2
#
#                               product_id                         seller_id  \
# 95528   0ef8c1b31d81d6b4453f70a61321f73e  fa1a9dec3a9940c072684a46728bf1fc
# 13299   53759a2ecddad2bb87a079a1f1519f73  1f50f920176fa81dab994f9023523100
# 781     8dfb2df51786c583001deb21b4a94080  4391ea5c5990502176a1dcda44a2373d
# ...

# %%
order_items_df.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
# std                                  NaN       0.705124
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %%
order_items_products_df = pd.merge(
  left=order_items_df,
  right=products_df,
  how="inner",
  left_on="product_id",
  right_on="product_id"
)

# %%
order_items_products_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  130898c0987d1801452a8ed92a670612              1
# 2  532ed5e14e24ae1f0d735b91524b98b9              1
# 3  6f8c31653edb8c83e1a739408b5ff750              1
# 4  7d19f4ef4d04461989632411b7e588b9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 2  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 3  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 4  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
#
#   shipping_limit_date  price  freight_value product_category_name  \
# 0 2017-09-19 09:45:35   58.9          13.29            cool_stuff
# 1 2017-07-05 02:44:11   55.9          17.96            cool_stuff
# ...

# %%
products_orders_items_df = pd.merge(
  left=products_df,
  right=order_items_df,
  how="inner",
  left_on="product_id",
  right_on="product_id"
)

products_orders_items_df.head(10)
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
# 5  41d3672d4792049fa1779bb35283ed13  instrumentos_musicais
# 6  732bd381ad09e530fe0a5f457d81becb             cool_stuff
# 7  732bd381ad09e530fe0a5f457d81becb             cool_stuff
# 8  2548af3e6e77a690cf3eb6368e9ab61e       moveis_decoracao
# 9  2548af3e6e77a690cf3eb6368e9ab61e       moveis_decoracao
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# ...

# %%
# melihat produk paling banyak terjual dan paling sedikit terjual
products_orders_items_df.groupby("product_category_name_english").order_id.nunique().sort_values(ascending=False)
# Out:
# product_category_name_english
# bed_bath_table               9417
# health_beauty                8836
# sports_leisure               7720
# computers_accessories        6689
# furniture_decor              6449
#                              ...
# arts_and_craftmanship          23
# la_cuisine                     13
# cds_dvds_musicals              12
# fashion_childrens_clothes       8
# security_and_services           2
# Name: order_id, Length: 71, dtype: int64

# %%
top_sold = products_orders_items_df.groupby("product_category_name_english").order_id.nunique().sort_values(ascending=False)
top_sold.head(15)
# Out:
# product_category_name_english
# bed_bath_table           9417
# health_beauty            8836
# sports_leisure           7720
# computers_accessories    6689
# furniture_decor          6449
# housewares               5884
# watches_gifts            5624
# telephony                4199
# auto                     3897
# toys                     3886
# cool_stuff               3632
# garden_tools             3518
# perfumery                3162
# baby                     2884
# electronics              2550
# Name: order_id, dtype: int64

# %%
lowest_sold =  products_orders_items_df.groupby("product_category_name_english").order_id.nunique().sort_values(ascending=True)
lowest_sold.head(15)
# Out:
# product_category_name_english
# security_and_services                 2
# fashion_childrens_clothes             8
# cds_dvds_musicals                    12
# la_cuisine                           13
# arts_and_craftmanship                23
# home_comfort_2                       24
# diapers_and_hygiene                  27
# fashion_sport                        27
# flowers                              29
# music                                38
# furniture_mattress_and_upholstery    38
# party_supplies                       39
# fashio_female_clothing               39
# books_imported                       53
# dvds_blu_ray                         59
# Name: order_id, dtype: int64

# %% [markdown]
# ### Explore Order Reviews & Order Items

# %%
order_reviews_orders_df = pd.merge(
  left=order_reviews_df,
  right=order_items_df,
  how="inner",
  left_on="order_id",
  right_on="order_id"
)
order_reviews_orders_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 2  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 3  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 4  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
#
#    review_score review_comment_title                 review_comment_message  \
# 0             4                  NaN                                    NaN
# 1             4                  NaN                                    NaN
# 2             5                  NaN                                    NaN
# 3             5                  NaN                                    NaN
# 4             5                  NaN  Recebi bem antes do prazo estipulado.
#
#   review_creation_date review_answer_timestamp  order_item_id  \
# ...

# %% [markdown]
# ### Explore All Data Product, Order Items & Order Reviews

# %%
all_df = pd.merge(
  left=order_reviews_orders_df,
  right=products_df,
  how="left",
  left_on="product_id",
  right_on="product_id"
)

all_df
# Out:
#                                review_id                          order_id  \
# 0       7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1       7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 2       80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 3       228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 4       e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# ...                                  ...                               ...
# 112367  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 112368  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 112369  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 112370  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 112371  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#         review_score review_comment_title  \
# ...

# %%
all_df.groupby("product_category_name_english").order_id.nunique().sort_values(ascending=False)
# Out:
# product_category_name_english
# bed_bath_table               9313
# health_beauty                8771
# sports_leisure               7669
# computers_accessories        6649
# furniture_decor              6398
#                              ...
# arts_and_craftmanship          23
# la_cuisine                     12
# cds_dvds_musicals              12
# fashion_childrens_clothes       8
# security_and_services           2
# Name: order_id, Length: 71, dtype: int64

# %%
review_counts_df = all_df.groupby("product_category_name_english").agg({
  "review_id": "nunique",
  "review_score": ["min", "max", "mean"]
})

review_counts_df.describe()
# Out:
#          review_id review_score
#            nunique          min        max       mean
# count    71.000000    71.000000  71.000000  71.000000
# mean   1370.492958     1.028169   4.985915   4.040659
# std    2255.587417     0.237356   0.118678   0.294459
# min       2.000000     1.000000   4.000000   2.500000
# 25%      85.500000     1.000000   5.000000   3.943434
# 50%     246.000000     1.000000   5.000000   4.055019
# 75%    1482.500000     1.000000   5.000000   4.173728
# max    9324.000000     3.000000   5.000000   4.642857

# %%
top_review = review_counts_df.sort_values(("review_score", "mean"), ascending=False).head(20)
top_review
# Out:
#                                       review_id review_score
#                                         nunique          min max      mean
# product_category_name_english
# cds_dvds_musicals                            12            3   5  4.642857
# fashion_childrens_clothes                     8            1   5  4.500000
# books_general_interest                      508            1   5  4.446266
# costruction_tools_tools                      94            1   5  4.444444
# flowers                                      28            1   5  4.419355
# books_imported                               53            1   5  4.400000
# books_technical                             259            1   5  4.368421
# food_drink                                  226            1   5  4.315412
# luggage_accessories                        1030            1   5  4.315257
# small_appliances_home_oven_and_coffee        75            1   5  4.302632
# ...

# %%
lowest_review = review_counts_df.sort_values(("review_score", "mean"), ascending=True).head(20)
lowest_review
# Out:
#                                         review_id review_score
#                                           nunique          min max      mean
# product_category_name_english
# security_and_services                           2            1   4  2.500000
# diapers_and_hygiene                            27            1   5  3.256410
# office_furniture                             1265            1   5  3.493183
# home_comfort_2                                 23            1   5  3.629630
# fashion_male_clothing                         111            1   5  3.641221
# fixed_telephony                               215            1   5  3.683206
# party_supplies                                 39            1   5  3.767442
# fashio_female_clothing                         41            1   5  3.780000
# furniture_mattress_and_upholstery              38            1   5  3.815789
# audio                                         348            1   5  3.825485
# ...

# %%
top_review.head(40)
# Out:
#                                       review_id review_score
#                                         nunique          min max      mean
# product_category_name_english
# cds_dvds_musicals                            12            3   5  4.642857
# fashion_childrens_clothes                     8            1   5  4.500000
# books_general_interest                      508            1   5  4.446266
# costruction_tools_tools                      94            1   5  4.444444
# flowers                                      28            1   5  4.419355
# books_imported                               53            1   5  4.400000
# books_technical                             259            1   5  4.368421
# food_drink                                  226            1   5  4.315412
# luggage_accessories                        1030            1   5  4.315257
# small_appliances_home_oven_and_coffee        75            1   5  4.302632
# ...

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Produk apa saja yang paling diminati dan paling sedikit diminati oleh pelanggan?

# %%
product_sum_order_df = all_df.groupby("product_category_name_english").order_id.nunique().sort_values(ascending=False).reset_index()
product_sum_order_df.columns = ["product_category", "sum_order"]
product_sum_order_df
# Out:
#              product_category  sum_order
# 0              bed_bath_table       9313
# 1               health_beauty       8771
# 2              sports_leisure       7669
# 3       computers_accessories       6649
# 4             furniture_decor       6398
# ..                        ...        ...
# 66      arts_and_craftmanship         23
# 67                 la_cuisine         12
# 68          cds_dvds_musicals         12
# 69  fashion_childrens_clothes          8
# 70      security_and_services          2
#
# [71 rows x 2 columns]

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#164863", "#B6BBC4", "#B6BBC4", "#B6BBC4", "#B6BBC4"]

sns.barplot(x="sum_order", y="product_category", data=product_sum_order_df.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Product", loc="center", fontsize=18)
ax[0].tick_params(axis ='y', labelsize=15)

sns.barplot(x="sum_order", y="product_category", data=product_sum_order_df.sort_values(by="sum_order", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Product", loc="center", fontsize=18)
ax[1].tick_params(axis='y', labelsize=15)

plt.suptitle("Best and Worst Performing Product by Number of Sales", fontsize=20)
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Produk kategori apa yang memiliki review score paling baik dan paling rendah?

# %%
product_review_df = all_df.groupby("product_category_name_english").agg({
  "review_id": "nunique",
  "review_score": "mean"
}).reset_index()
product_review_df.rename(columns={
  "product_category_name_english": "product_category",
  "review_id": "sum_review",
  "review_score": "review_score_avg"
}, inplace=True)

product_review_df.sort_values(by="review_score_avg", ascending=False)
# Out:
#              product_category  sum_review  review_score_avg
# 11          cds_dvds_musicals          12          4.642857
# 29  fashion_childrens_clothes           8          4.500000
# 8      books_general_interest         508          4.446266
# 22    costruction_tools_tools          94          4.444444
# 35                    flowers          28          4.419355
# ..                        ...         ...               ...
# 30      fashion_male_clothing         111          3.641221
# 46             home_comfort_2          23          3.629630
# 57           office_furniture        1265          3.493183
# 23        diapers_and_hygiene          27          3.256410
# 61      security_and_services           2          2.500000
#
# [71 rows x 3 columns]

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#164863", "#B6BBC4", "#B6BBC4", "#B6BBC4", "#B6BBC4"]

sns.barplot(x="review_score_avg", y="product_category", data=product_review_df.sort_values(by="review_score_avg", ascending=False).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Product", loc="center", fontsize=18)
ax[0].tick_params(axis ='y', labelsize=15)

sns.barplot(x="review_score_avg", y="product_category", data=product_review_df.sort_values(by="review_score_avg", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Product", loc="center", fontsize=18)
ax[1].tick_params(axis='y', labelsize=15)

plt.suptitle("Best and Worst Performing Product by Number of Sales", fontsize=20)
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### Conclusion Pertanyaan 1

# %% [markdown]
# Dapat dilihat pada visualisasi yang telah dibuat sebelumnya, produk yang paling banyak diminati oleh customer adalah produk kategori bad_bath_table dan produk paling sedikit diminati adalah produk kategori security_and_services.

# %% [markdown]
# ### Conclusion Pertanyaan 2

# %% [markdown]
# Berdasarkan data visualisasi diatas, dapat dilihat jika produk kategori cds_dvds_musicals merupakan produk dengan review score terbaik mendapatkan review score sebesar 4.642857. Sedangkan produk kategori security_and_services merupakan produk dengan review score terendah dengan mendapatkan score sebesar 2.500000.
